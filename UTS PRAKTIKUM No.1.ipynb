# %% [markdown]
# ### Import Library

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image

# %% [markdown]
# ### Membaca Gambar

# %%
img = cv2.imread('Nomor 1.jpg')

# %%
img.shape
# Out:
# (2084, 3704, 3)

# %%
[baris, kolom] = img.shape[:2]

# %% [markdown]
# ### Convert BGR to RGB

# %%
rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %% [markdown]
# ### Deteksi Warna

# %%
image_path = "Nomor 1.jpg"  
img = Image.open(image_path).convert("RGB")
rgb = np.array(img)

red_channel = rgb[:, :, 0]   
green_channel = rgb[:, :, 1]  
blue_channel = rgb[:, :, 2]   

fig, axs = plt.subplots(2, 2, figsize=(10, 8))

axs[0, 0].imshow(rgb)
axs[0, 0].set_title("CITRA ASLI")
axs[0, 0].axis('off')

axs[0, 1].imshow(red_channel, cmap='gray')
axs[0, 1].set_title("MERAH")
axs[0, 1].axis('off')

axs[1, 0].imshow(green_channel, cmap='gray')
axs[1, 0].set_title("HIJAU")
axs[1, 0].axis('off')

# Channel Biru (Grayscale)
axs[1, 1].imshow(blue_channel, cmap='gray')
axs[1, 1].set_title("BIRU")
axs[1, 1].axis('off')

plt.tight_layout()
plt.show()

plt.figure(figsize=(12, 4))

colors = ('red', 'green', 'blue')
channels = [red_channel, green_channel, blue_channel]
titles = ['Histogram Merah', 'Histogram Hijau', 'Histogram Biru']

for i, (channel, color, title) in enumerate(zip(channels, colors, titles)):
    plt.subplot(1, 3, i + 1)
    plt.hist(channel.ravel(), bins=256, color=color, alpha=0.7)
    plt.title(title)
    plt.xlabel('Intensitas')
    plt.ylabel('Jumlah Piksel')
    plt.xlim([0, 256])

plt.tight_layout()
plt.show()
